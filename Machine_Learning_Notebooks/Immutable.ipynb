# %% [markdown]
# ![image.png](attachment:95d727dc-e07d-416e-947d-31fdc81eab6a.png)

# %%
s1 = "Hello World"
s1[0] = "K"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 s1 = "Hello World"
# ----> 2 s1[0] = "K"
#
# TypeError: 'str' object does not support item assignment
